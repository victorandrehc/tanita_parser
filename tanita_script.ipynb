# %%
import tanita_parser
import tabulate

# %%
filename = "DATA1.CSV"
with open(filename, "r") as file:
    data = tanita_parser.parse_tanita_csv(file)
print(data)
# Out:
# {'{0': ['16', '16'], '~0': ['2', '2'], '~1': ['2', '2'], '~2': ['3', '3'], '~3': ['4', '4'], 'MO': ['BC-601', 'BC-601'], 'DT': ['10/02/2025', '10/02/2025'], 'Ti': ['21:46:07', '21:58:09'], 'Bt': ['0', '0'], 'GE': ['1', '1'], 'AG': [30.0, 30.0], 'Hm': [180.0, 180.0], 'AL': ['3', '3'], 'Wk': [90.3, 90.3], 'MI': [27.9, 27.9], 'FW': [25.3, 25.5], 'Fr': [23.7, 22.2], 'Fl': [22.9, 23.7], 'FR': [20.9, 20.0], 'FL': [20.7, 20.8], 'FT': [28.5, 29.1], 'mW': [64.1, 64.0], 'mr': [3.7, 3.8], 'ml': [3.8, 3.7], 'mR': [11.3, 11.4], 'mL': [11.2, 11.2], 'mT': [34.1, 33.9], 'bW': [3.3, 3.3], 'IF': [8.0, 8.0], 'rD': [4211.0, 4205.0], 'rA': [45.0, 45.0], 'ww': [52.2, 52.1], 'CS': ['01', 'FF'], 'datetime': [datetime.datetime(2025, 2, 10, 21, 46, 7), datetime.datetime(2025, 2, 10, 21, 58, 9)]}

# %%
tanita_parser.print_table(data)
# Out:
# +-----------------------------+---------------------+
# | Label                       | Most Recent Value   |
# +=============================+=====================+
# | Unknown_16                  | 16                  |
# +-----------------------------+---------------------+
# | Length unit                 | 2                   |
# +-----------------------------+---------------------+
# | Mass unit                   | 2                   |
# +-----------------------------+---------------------+
# | Unknown_4                   | 3                   |
# +-----------------------------+---------------------+
# | Unknown_3                   | 4                   |
# +-----------------------------+---------------------+
# | Model                       | BC-601              |
# +-----------------------------+---------------------+
# | Measurement Date            | 10/02/2025          |
# +-----------------------------+---------------------+
# | Measurement Time            | 21:58:09            |
# +-----------------------------+---------------------+
# | Athlete mode                | 0                   |
# +-----------------------------+---------------------+
# | Gender                      | 1                   |
# +-----------------------------+---------------------+
# | Age                         | 30.0                |
# +-----------------------------+---------------------+
# | Height                      | 180.0               |
# +-----------------------------+---------------------+
# | Activity Level              | 3                   |
# +-----------------------------+---------------------+
# | Body_mass [kg]              | 90.3                |
# +-----------------------------+---------------------+
# | BMI [Kg/m2]                 | 27.9                |
# +-----------------------------+---------------------+
# | Global Fat pct [%]          | 25.5                |
# +-----------------------------+---------------------+
# | Right Arm Fat [%]           | 22.2                |
# +-----------------------------+---------------------+
# | Left Arm Fat [%]            | 23.7                |
# +-----------------------------+---------------------+
# | Right Leg Fat [%]           | 20.0                |
# +-----------------------------+---------------------+
# | Left Leg Fat [%]            | 20.8                |
# +-----------------------------+---------------------+
# | Torso Fat[%]                | 29.1                |
# +-----------------------------+---------------------+
# | Global Muscle [%]           | 64.0                |
# +-----------------------------+---------------------+
# | Right Arm Muscle [%]        | 3.8                 |
# +-----------------------------+---------------------+
# | Left Arm Muscle [%]         | 3.7                 |
# +-----------------------------+---------------------+
# | Right Leg Muscle [%]        | 11.4                |
# +-----------------------------+---------------------+
# | Left Leg Muscle [%]         | 11.2                |
# +-----------------------------+---------------------+
# | Torso Muscle [%]            | 33.9                |
# +-----------------------------+---------------------+
# | Estimated_bone_mass [Kg]    | 3.3                 |
# +-----------------------------+---------------------+
# | Visceral_fat_rating         | 8.0                 |
# +-----------------------------+---------------------+
# | Daily_calorie_intake [Kcal] | 4205.0              |
# +-----------------------------+---------------------+
# | Metabolic_age               | 45.0                |
# +-----------------------------+---------------------+
# | Global_body_water_pct [%]   | 52.1                |
# +-----------------------------+---------------------+
# | Unknown_BC                  | FF                  |
# +-----------------------------+---------------------+
# | Datetime                    | 2025-02-10 21:58:09 |
# +-----------------------------+---------------------+

# %%
tanita_parser.plot_data(data)
